# %%
from datamations import *

df = DatamationFrame(small_salary().df)

df.groupby('Degree').mean().datamation_sanddance()

# %%
from palmerpenguins import load_penguins

df = DatamationFrame(load_penguins()) 
df.groupby(['species', 'island', 'sex']).mean('bill_length_mm').datamation_sanddance()
